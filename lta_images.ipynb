# %%
import numpy as np
import pandas as pd
import requests, re, zipfile, logging, sys
from datetime import datetime
from pathlib import Path

import folium
from IPython.display import display

# %%
traffic_images_url = "http://datamall2.mytransport.sg/ltaodataservice/Traffic-Imagesv2"
api_key = "AO4qMbK3S7CWKSlplQZqlA=="

headers = {
    'AccountKey' : api_key
}

# %%
# Load the camera info CSV file
df = pd.read_csv('camera_info.csv')

# Initialize a map centered on Singapore
singapore_map = folium.Map(location=[1.3521, 103.8198], zoom_start=12)

# Iterate over the rows of the DataFrame and add points to the map
for index, row in df.iterrows():
    lat = row['Latitude']
    lon = row['Longitude']
    camera_id = int(row['CameraID'])
    
    # Add a marker with a popup showing the camera ID and a tooltip for mouseover
    folium.Marker(
        location=[lat, lon],
        popup=f'Camera ID: {camera_id}',
        tooltip=camera_id  # Show the camera ID on hover
    ).add_to(singapore_map)

# Display the map in the notebook
display(singapore_map)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Load the camera info CSV file
# ----> 2 df = pd.read_csv('camera_info.csv')
#       4 # Initialize a map centered on Singapore
#       5 singapore_map = folium.Map(location=[1.3521, 103.8198], zoom_start=12)
#
# File e:\study-master\NUSCampus\sem1\IND5003\code\venv\lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File e:\study-master\NUSCampus\sem1\IND5003\code\venv\lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File e:\study-master\NUSCampus\sem1\IND5003\code\venv\lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File e:\study-master\NUSCampus\sem1\IND5003\code\venv\lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File e:\study-master\NUSCampus\sem1\IND5003\code\venv\lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'camera_info.csv'

# %%
outzipfile = "lta_images.zip"

try:
    r3 = requests.get(traffic_images_url, headers=headers)

    # retrieve images
    for ii in r3.json()['value']:
        img_link = ii['ImageLink'] 
        xx = re.search('.*(?<=.jpg)', img_link) 
        fname = re.split('/', xx.group())[-1]
        r4 = requests.get(img_link, headers=headers)
        
        with open(fname, 'wb') as f:
            f.write(r4.content)
            print(f'{fname} written..')
      
        with zipfile.ZipFile(outzipfile, 'a', zipfile.ZIP_DEFLATED) as ff:
            ff.write(fname)
            print(f'{fname} written to zip..')

        Path(fname).unlink()
    
except Exception as err: 
    print(f"Error {err} occurred.")
# Out:
# 1001_2333_20240825233509_975455.jpg written..
# 1001_2333_20240825233509_975455.jpg written to zip..
# 1002_2328_20240825233507_545599.jpg written..
# 1002_2328_20240825233507_545599.jpg written to zip..
# 1003_2328_20240825233506_524997.jpg written..
# 1003_2328_20240825233506_524997.jpg written to zip..
# 1004_2328_20240825233504_494810.jpg written..
# 1004_2328_20240825233504_494810.jpg written to zip..
# 1005_2328_20240825233504_999757.jpg written..
# 1005_2328_20240825233504_999757.jpg written to zip..
# 1006_2328_20240825233503_494857.jpg written..
# 1006_2328_20240825233503_494857.jpg written to zip..
# 1111_2322_20240825233541_102559.jpg written..
# 1111_2322_20240825233541_102559.jpg written to zip..
